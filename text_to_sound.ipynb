# %% [markdown]
# <a href="https://colab.research.google.com/github/amilsiddik/Deep-Learning/blob/main/text_to_sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
from gtts import gTTS

# %%
from IPython.display import Audio

# %%
tts=gTTS('Hai, apa kabar amil??',lang='id')
tts.save('1.wav')
sound_file='1.wav'
Audio(sound_file,autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
