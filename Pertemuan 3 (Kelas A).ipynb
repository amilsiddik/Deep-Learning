# %% [markdown]
# <a href="https://colab.research.google.com/github/amilsiddik/Deep-Learning/blob/main/Pertemuan%203%20(Kelas%20A).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-98857953-38ce-49a2-a02b-2e99ee1e1c8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98857953-38ce-49a2-a02b-2e99ee1e1c8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "goal leagues"
# Out:
# ref                                                      title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# slehkyi/extended-football-stats-for-european-leagues-xg  Football Data: Expected Goals and Other Metrics    1MB  2020-08-02 17:28:39           5501        145  1.0
# vivovinco/nba-player-stats                               2021-2022 NBA Player Stats                        48KB  2022-06-18 07:52:52           5630        116  1.0
# sanjeetsinghnaik/most-expensive-footballers-2021         Most Expensive Footballers 2021                   13KB  2021-12-03 20:28:03           1799         46  1.0
# ...

# %%
# !kaggle datasets download -d sanjeetsinghnaik/most-expensive-footballers-2021
# Out:
# ...
#   0% 0.00/13.3k [00:00<?, ?B/s]
# 100% 13.3k/13.3k [00:00<00:00, 12.3MB/s]

# %%
# !unzip most-expensive-footballers-2021.zip
# Out:
# Archive:  most-expensive-footballers-2021.zip
#   inflating: players.csv

# %%
import pandas as pd
df = pd.read_csv('/content/players.csv')

# %%
df
# Out:
#      Unnamed: 0                    Name            Position  Age  \
# 0             0           Kylian Mbappé      Centre-Forward   22
# 1             1          Erling Haaland      Centre-Forward   21
# 2             2              Harry Kane      Centre-Forward   28
# 3             3           Jack Grealish         Left Winger   26
# 4             4           Mohamed Salah        Right Winger   29
# ..          ...                     ...                 ...  ...
# 495         495  Giorgian de Arrascaeta  Attacking Midfield   27
# 496         496             Ayoze Pérez      Second Striker   28
# 497         497              Alex Meret          Goalkeeper   24
# 498         498         Duje Caleta-Car         Centre-Back   25
# 499         499         Aritz Elustondo         Centre-Back   27
#
#      Markey Value In Millions(£)  Country                          Club  \
# 0                          144.0   France           Paris Saint-Germain
# ...
