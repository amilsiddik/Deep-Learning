# %% [markdown]
# <a href="https://colab.research.google.com/github/amilsiddik/Deep-Learning/blob/main/Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
apel = pd.Series([5,2,0,1])

# %%
jeruk = pd.Series([0,3,8,2], index=[1,2,3,4])

# %%
print(apel)
# Out:
# 0    5
# 1    2
# 2    0
# 3    1
# dtype: int64

# %%
print(jeruk)
# Out:
# 1    0
# 2    3
# 3    8
# 4    2
# dtype: int64

# %%
jeruk.index=['a','b','c','d']

# %%
print(jeruk)
# Out:
# a    0
# b    3
# c    8
# d    2
# dtype: int64

# %%
print(jeruk['c'])
# Out:
# 8

# %%
df1 = pd.DataFrame([3,2,0,1],columns=['apel'],index=[1,2,3,4])

# %%
df1
# Out:
#    apel
# 1     3
# 2     2
# 3     0
# 4     1

# %%
dict1 = {'apel':[5,2,0,1],'jeruk':[0,3,8,2]}
df1 = pd.DataFrame(dict1)
df1
# Out:
#    apel  jeruk
# 0     5      0
# 1     2      3
# 2     0      8
# 3     1      2

# %%
df1.count()
# Out:
# apel     4
# jeruk    4
# dtype: int64

# %%
df1.sum()
# Out:
# apel      8
# jeruk    13
# dtype: int64

# %%
df1.describe()
# Out:
#            apel    jeruk
# count  4.000000  4.00000
# mean   2.000000  3.25000
# std    2.160247  3.40343
# min    0.000000  0.00000
# 25%    0.750000  1.50000
# 50%    1.500000  2.50000
# 75%    2.750000  4.25000
# max    5.000000  8.00000

# %%
buahapel = df1.apel
buahapel
# Out:
# 0    5
# 1    2
# 2    0
# 3    1
# Name: apel, dtype: int64

# %%
jerukapel = df1 [['jeruk', 'apel']]
jerukapel
# Out:
#    jeruk  apel
# 0      0     5
# 1      3     2
# 2      8     0
# 3      2     1

# %%
jerukapel[2:]
# Out:
#    jeruk  apel
# 2      8     0
# 3      2     1

# %%
jerukapel['jeruk']>2
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: jeruk, dtype: bool

# %%
jerukapel[jerukapel['jeruk']>2]
# Out:
#    jeruk  apel
# 1      3     2
# 2      8     0

# %%
jerukapel
# Out:
#    jeruk  apel
# 0      0     5
# 1      3     2
# 2      8     0
# 3      2     1

# %%
jerukapel.head(2)
# Out:
#    jeruk  apel
# 0      0     5
# 1      3     2

# %%
jerukapel.T
# Out:
#        0  1  2  3
# jeruk  0  3  8  2
# apel   5  2  0  1

# %% [markdown]
# # Menggunakan index

# %%
jerukapel.iloc[3]
# Out:
# jeruk    2
# apel     1
# Name: 3, dtype: int64

# %%
jerukapel.iloc[[1,2]]
# Out:
#    jeruk  apel
# 1      3     2
# 2      8     0

# %%
jerukapel[:2]
# Out:
#    jeruk  apel
# 0      0     5
# 1      3     2

# %%
df2 =pd.DataFrame([1,2,2,3,4,5,5,6,7])
df2
# Out:
#    0
# 0  1
# 1  2
# 2  2
# 3  3
# 4  4
# 5  5
# 6  5
# 7  6
# 8  7

# %%
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
df2 = df2.drop_duplicates(keep='first')
df2
# Out:
#    0
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 7  6
# 8  7

# %%
df2 =pd.DataFrame([1,2,2,3,4,5,5,6,7],columns=['nilai'])
df2
# Out:
#    nilai
# 0      1
# 1      2
# 2      2
# 3      3
# 4      4
# 5      5
# 6      5
# 7      6
# 8      7

# %%
df2 = df2.drop_duplicates(keep='first')
df2
# Out:
#    nilai
# 0      1
# 1      2
# 3      3
# 4      4
# 5      5
# 7      6
# 8      7

# %%
df3 = pd.DataFrame([1,2, None, 4, 5, None],columns=['nilai'])
df3
# Out:
#    nilai
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN

# %%
df4 = df3.dropna()

# %%
df4
# Out:
#    nilai
# 0    1.0
# 1    2.0
# 3    4.0
# 4    5.0

# %%
df5 = df3.fillna(3)
df5
# Out:
#    nilai
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    3.0

# %%
df3
# Out:
#    nilai
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN

# %%
mean_x = df3['nilai'].mean()
mean_x
# Out:
# 3.0

# %% [markdown]
# ***Membaca File**

# %%
df6 = pd.read_csv('/content/drive/MyDrive/dataset latihan/List of countries by carbon dioxide emissions.csv')

# %%
df6
# Out:
#                            Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                              NaN                      1990.000    2005.000
# 1                            World                     22674.116   30049.809
# 2    World  International Aviation                       258.941     422.777
# 3    World  International Shipping                       371.804     572.169
# 4                      Afghanistan                         2.546       1.063
# ..                             ...                           ...         ...
# 208                        Vietnam                        20.182      99.231
# 209                 Western Sahara                         0.144       0.227
# 210                          Yemen                         6.887      21.768
# 211                         Zambia                         2.955       2.457
# 212                       Zimbabwe                        17.178      11.388
#
# ...

# %%
df6.describe()
# Out:
#        Fossil CO2 emissions(Mt CO2)    Unnamed: 2    Unnamed: 3
# count                    213.000000    213.000000    213.000000
# mean                     243.016573    311.421516    374.298817
# std                     1636.415890   2161.040668   2680.033230
# min                        0.001000      0.002000      0.002000
# 25%                        0.684000      1.119000      1.771000
# 50%                        5.851000      7.806000     11.422000
# 75%                       57.242000     61.396000     72.249000
# max                    22674.116000  30049.809000  37077.404000

# %%
df7 = df6.dropna()
df7
# Out:
#          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  Unnamed: 3  \
# 1          World                     22674.116   30049.809   37077.404
# 4    Afghanistan                         2.546       1.063      11.422
# 5        Albania                         6.583       4.196       5.026
# 6        Algeria                        65.677      98.197     159.929
# 7         Angola                         5.851      15.975      30.876
# ..           ...                           ...         ...         ...
# 207    Venezuela                       109.268     152.464     145.877
# 208      Vietnam                        20.182      99.231     218.729
# 210        Yemen                         6.887      21.768      12.503
# 211       Zambia                         2.955       2.457       4.967
# 212     Zimbabwe                        17.178      11.388      12.087
#
#     Fossil CO2 emissions Unnamed: 5 2017  Fossil CO2 emissions Unnamed: 7  \
# ...
